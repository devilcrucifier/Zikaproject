# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('cdc_zika.csv')

# %%
data.head(1)
# Out:
#   report_date                location location_type  \
# 0  2016-03-19  Argentina-Buenos_Aires      province
#
#                          data_field data_field_code  time_period  \
# 0  cumulative_confirmed_local_cases          AR0001          NaN
#
#    time_period_type value   unit
# 0               NaN     0  cases

# %%
data.drop(data.columns[[2,5,6,8]], axis=1, inplace=True)

# %%
data.head(1)
# Out:
#   report_date                location                        data_field  \
# 0  2016-03-19  Argentina-Buenos_Aires  cumulative_confirmed_local_cases
#
#   data_field_code value
# 0          AR0001     0

# %%
data[data.data_field == "confirmed_male"].value.plot()

data[data.data_field == "confirmed_female"].value.plot().legend(("Male","Female"),loc="best")

plt.title("Confirmed Male vs Female cases")

# %%
data['country'] = data['location']
data['country'] = data['country'].astype(str)
data['country'] = data['country'].apply(lambda x: pd.Series(x.split('-')))
country=data.country.unique()

# %%
data.head(1)
# Out:
#   report_date                location                        data_field  \
# 0  2016-03-19  Argentina-Buenos_Aires  cumulative_confirmed_local_cases
#
#   data_field_code value    country
# 0          AR0001     0  Argentina

# %%
data.country.value_counts().plot(kind='bar', figsize=(12, 7))
plt.title("Number of Locations with Zika Virus")
plt.ylabel("Number of Cases")
plt.xlabel("Country")

# %%
data.drop(data.columns[[0,1,2,3]], axis=1, inplace=True)

# %%
data.country.value_counts().plot(kind='bar', figsize=(12, 7))
plt.title("Number of Locations with Zika Virus")
plt.ylabel("Number of Cases")
plt.xlabel("Country")

# %%
data['grouped_country'] = data['country']
data['grouped_country'] = data['grouped_country'].astype(str)
data['grouped_country'] = data.groupby(['country'])
grouped_country=data.grouped_country.unique()
data.apply(lambda col: col.drop_duplicates().reset_index(drop=True))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-c69549d0dce9> in <module>()
#       1 data['grouped_country'] = data['country']
# ----> 2 data['grouped_country'] = data.groupby(['country'])
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2355         else:
#    2356             # set column
# -> 2357             self._set_item(key, value)
#    2358
#    2359     def _setitem_slice(self, key, value):
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2421
#    2422         self._ensure_valid_index(value)
# -> 2423         value = self._sanitize_column(key, value)
#    2424         NDFrame._set_item(self, key, value)
#    2425
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value)
#    2576
# ...

# %%
grouped

# %%
grouped.plot(kind='bar', figsize=(12, 7))
plt.title("Reported with Zika Virus")
plt.ylabel("Number of Cases")
plt.xlabel("Country")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-5db2599d9bdc> in <module>()
# ----> 1 grouped.plot(kind='bar', figsize=(12, 7))
#       2 plt.title("Reported with Zika Virus")
#       3 plt.ylabel("Number of Cases")
#       4 plt.xlabel("Country")
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\groupby.py in __call__(self, *args, **kwargs)
#     309             return self.plot(*args, **kwargs)
#     310         f.__name__ = 'plot'
# --> 311         return self._groupby.apply(f)
#     312
#     313     def __getattr__(self, name):
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\groupby.py in apply(self, func, *args, **kwargs)
#     649         # ignore SettingWithCopy here in case the user mutates
#     650         with option_context('mode.chained_assignment', None):
# --> 651             return self._python_apply_general(f)
# ...
